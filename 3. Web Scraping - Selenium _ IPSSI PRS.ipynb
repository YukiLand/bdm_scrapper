# %% [markdown]
# # 3. Web Scraping - Selenium
#
# <img src = 'https://xn--kvin-duranty-beb.fr/wp-content/uploads/2022/10/Web-Scraping-_-IPSSI-PRS-2.png' >
#
#
#
# Dans cet exercice, nous utiliserons la bibliothèque Selenium afin de collecter les données des sites internet suivants :
#
# - Partie 1 : [Doctolib](https://www.doctolib.fr/dentiste/paris)
# Nous continuerons là où Beautifullsoup montrait ses limites en collectant de manière automatisée toutes les pages référencées par Doctolib.
#
#
# - Partie 2 : [Les Echos](https://www.lesechos.fr/)
# Nous collecterons les articles correspondants à la thématique `Intelligence artificielle`.
#
#
#
# # **Partie 1 - [Doctolib](https://www.doctolib.fr/)**
#
#
# <img src='https://upload.wikimedia.org/wikipedia/fr/thumb/7/7f/Logo-doctolib.svg/640px-Logo-doctolib.svg.png'>
#
#
# Les informations que nous souhaitons collecter sont les suivantes :
# - le nom du praticien
# - la profession du praticien
# - l'adresse du praticien
# - la ville du praticien
# - l'image de la fiche Doctolib du praticien
#
#
#
# ## 3.1 Installez la bibliothèque Selenium
# Utilitisez la commande suivante dans votre terminal :  `pip install selenium`

# %% [markdown]
# ## 3.2 Télécharger le webdriver [chrome](https://chromedriver.chromium.org/downloads)
# Placez le ensuite dans le dossier Web-scraping

# %% [markdown]
# ## 3.3 Importer l'objet `webdriver`de la bibliothèque de `selenium`
# Importez également `By` depuis `selenium.webdriver.common.by`

# %%
from selenium import webdriver
import time
from selenium.webdriver.common.by import By

# %% [markdown]
# ## 3.4 Deffinissez une variable `driver = webdriver.Chrome(DRIVER_PATH)`.
# Où `DRIVER_PATH` est le chemin du web driver téléchargé à la question **3.2** ==> `"./chromedriver"`.

# %%
driver = webdriver.Chrome("./chromedriver")
# Out:
# C:\Users\antoi\AppData\Local\Temp\ipykernel_13780\3854778951.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("./chromedriver")

# %% [markdown]
# ## 3.5 Utilisez la méthode `get(BASE_URL)` de l'objet `driver` puis notez vos observations.
# `BASE_URL`est le lien pointant vers le site de Doctolib `"https://www.doctolib.fr/dentiste/paris"`

# %%
driver.get("https://www.doctolib.fr/dentiste/paris")

# %%
driver.find_element(By.CLASS_NAME, "didomi-components-button didomi-button didomi-dismiss-button didomi-components-button--color didomi-button-highlight highlight-button".replace(' ', '.'))
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="3ef04251759649b1c2ca93f04daf345f", element="0D4CCE4D9A241907831816DBC97E4253_element_9")>

# %%
driver.find_elements(By.TAG_NAME, "button")
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="3ef04251759649b1c2ca93f04daf345f", element="0D4CCE4D9A241907831816DBC97E4253_element_10")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3ef04251759649b1c2ca93f04daf345f", element="0D4CCE4D9A241907831816DBC97E4253_element_11")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3ef04251759649b1c2ca93f04daf345f", element="0D4CCE4D9A241907831816DBC97E4253_element_9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3ef04251759649b1c2ca93f04daf345f", element="0D4CCE4D9A241907831816DBC97E4253_element_12")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3ef04251759649b1c2ca93f04daf345f", element="0D4CCE4D9A241907831816DBC97E4253_element_13")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3ef04251759649b1c2ca93f04daf345f", element="0D4CCE4D9A241907831816DBC97E4253_element_14")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3ef04251759649b1c2ca93f04daf345f", element="0D4CCE4D9A241907831816DBC97E4253_element_15")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3ef04251759649b1c2ca93f04daf345f", element="0D4CCE4D9A241907831816DBC97E4253_element_16")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3ef04251759649b1c2ca93f04daf345f", element="0D4CCE4D9A241907831816DBC97E4253_element_17")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3ef04251759649b1c2ca93f04daf345f", element="0D4CCE4D9A241907831816DBC97E4253_element_18")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3ef04251759649b1c2ca93f04daf345f", element="0D4CCE4D9A241907831816DBC97E4253_element_19")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3ef04251759649b1c2ca93f04daf345f", element="0D4CCE4D9A241907831816DBC97E4253_element_20")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3ef04251759649b1c2ca93f04daf345f", element="0D4CCE4D9A241907831816DBC97E4253_element_21")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3ef04251759649b1c2ca93f04daf345f", element="0D4CCE4D9A241907831816DBC97E4253_element_22")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3ef04251759649b1c2ca93f04daf345f", element="0D4CCE4D9A241907831816DBC97E4253_element_23")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3ef04251759649b1c2ca93f04daf345f", element="0D4CCE4D9A241907831816DBC97E4253_element_24")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3ef04251759649b1c2ca93f04daf345f", element="0D4CCE4D9A241907831816DBC97E4253_element_25")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="3ef04251759649b1c2ca93f04daf345f", element="0D4CCE4D9A241907831816DBC97E4253_element_26")>]

# %%
driver.find_element(By.ID, "didomi-notice-agree-button").click()

# %%
from selenium.webdriver.common.keys import Keys

# %%
Keys.ENTER
# Out:
# '\ue007'

# %%
driver.find_element(By.ID, ":r0:").send_keys(Keys.BACK_SPACE*100)
driver.find_element(By.ID, ":r0:").send_keys("Dentiste Paris")

time.sleep(2)

driver.find_element(By.CLASS_NAME, "Tappable-inactive dl-button-primary searchbar-submit-button dl-button dl-button-size-medium".replace(' ', '.')).click()

# %%
# driver.close() # close the current tab
# driver.quit() # close the entire browser

# %% [markdown]
# ## 3.6 Affichez l'adresse url courante ainsi que le titre de la page.

# %%
time.sleep(5)
print(driver.current_url)
print(driver.title)
# Out:
# https://www.doctolib.fr/dentiste/paris
# Chirurgien-dentiste Paris 75000 : Prenez rendez-vous en ligne | Doctolib

# %% [markdown]
# ## 3.7 Récupérez dans une variable `selection` la liste des praticients présents sur la page.
# Utilisez la méthéode `find_elements`, cette méthode prend deux arguments `By.CLASS_NAME` ainsi que le nom de la class recherchée sur la page.

# %%
selection = driver.find_elements(By.CLASS_NAME, "dl-search-result-presentation")

print(len(selection))
print(selection[0].text)
# Out:
# 20
# Dr Virginie Rubinstenn
# Chirurgien-dentiste
# 31 Avenue d'Italie
# 75013 Paris
# Conventionné
# PRENDRE RENDEZ-VOUS

# %% [markdown]
# ## 3.8 Affichez les information du premier élément de `selection` via son instance `text``.

# %%
print(selection[0].text)
# Out:
# Dr Virginie Rubinstenn
# Chirurgien-dentiste
# 31 Avenue d'Italie
# 75013 Paris
# Conventionné
# PRENDRE RENDEZ-VOUS

# %% [markdown]
# ## 3.9 Recherchez à nouveau à l'aide de la méthode `find_element` la photo du premier praticien figurant dans la liste ``selection``.

# %%
img = selection[0].find_element(By.CLASS_NAME, "dl-image dl-image-rounded".replace(' ', '.'))

# %% [markdown]
# ## 3.10 Récupérez à présent le lien de cette image en utilisant la méthode `get_attribute`.

# %%
img.get_attribute("src")
# Out:
# 'https://media.doctolib.com/image/upload/q_auto:eco,f_auto,dpr_2/w_62,h_62,c_fill,g_face/egi9evumdphjhhkvnphi'

# %% [markdown]
# ## 3.11 Créez une fonction `collect_data` qui renvoie un fichier `json` contenant les informations de tous les praticiens ainsi que leurs photos de profil.

# %%
def collect_data(selection):
    data = []
    for item in selection:
        img = item.find_element(By.CLASS_NAME, "dl-image dl-image-rounded".replace(' ', '.'))
        name = item.text.replace('\n', ' ')
        data.append([name, img.get_attribute("src")])
    return data

# %%
collectedData = collect_data(selection)

# %% [markdown]
# ## 3.9 Automatisez la collecte sur les pages 5 premières pages de résultats.

# %%
nbPage = 5
i = 1
while i < nbPage:
    i += 1
    driver.get("https://www.doctolib.fr/dentiste/paris?page={}".format(i))
    selection = driver.find_elements(By.CLASS_NAME, "dl-search-result-presentation")
    collectedData += collect_data(selection)
    time.sleep(3)

# %%
print(collectedData)

driver.close() # close the current tab
# Out:
# [["Dr Virginie Rubinstenn Chirurgien-dentiste 31 Avenue d'Italie 75013 Paris Conventionné PRENDRE RENDEZ-VOUS", 'https://media.doctolib.com/image/upload/q_auto:eco,f_auto,dpr_2/w_62,h_62,c_fill,g_face/egi9evumdphjhhkvnphi'], ['Dr Brice RIERA Chirurgien-dentiste 3 Bis Rue Léo Delibes 75116 Paris PRENDRE RENDEZ-VOUS', 'https://media.doctolib.com/image/upload/q_auto:eco,f_auto,dpr_2/w_62,h_62,c_fill,g_face/p1nfiuvpylh1af6vhjc1'], ['Dr Mathilde Grassin Chirurgien-dentiste 156 Rue de la Croix Nivert 75015 Paris PRENDRE RENDEZ-VOUS', 'https://media.doctolib.com/image/upload/q_auto:eco,f_auto,dpr_2/w_62,h_62,c_fill,g_face/zywamacgy2ubu6ffetcn'], ['Dr Natacha NIEZ Orthodontiste 97 Boulevard Diderot 75012 Paris PRENDRE RENDEZ-VOUS', 'https://media.doctolib.com/image/upload/q_auto:eco,f_auto,dpr_2/w_62,h_62,c_fill,g_face/n1zm8m5uikhlzpponk0j'], ['Dr Elena Schacher Chirurgien-dentiste 68 Avenue de Versailles 75016 Paris Conventionné PRENDRE RENDEZ-VOUS', 'https://media.doctolib.com/image/upload/q_auto:eco,f_auto,dpr_2/w_62,h_62,c_fill,g_face/vhlvbgubbws35775y96z'], ['Dr James ACHOUR Chirurgien-dentiste 4 Bis Rue de Lyon 75012 Paris Conventionné PRENDRE RENDEZ-VOUS', 'https://media.doctolib.com/image/upload/q_auto:eco,f_auto,dpr_2/w_62,h_62,c_fill,g_face/c3fnqidubwqztmc456y7'], ['Dr Thierry HOUR Chirurgien-dentiste 110 Rue de Montreuil 75011 Paris Conventionné PRENDRE RENDEZ-VOUS', 'https://media.doctolib.com/image/upload/q_auto:eco,f_auto,dpr_2/w_62,h_62,c_fill,g_face/jo5xm9anjvzeywjeygwb'], ["Dr Sara MORAIS Chirurgien-dentiste 14 Bis Boulevard de l'Hôpital 75005 Paris PRENDRE RENDEZ-VOUS", 'https://media.doctolib.com/image/upload/q_auto:eco,f_auto,dpr_2/w_62,h_62,c_fill,g_face/default_doctor_avatar_m'], ['Lon STRIMBU Chirurgien-dentiste 12 Rue du Faubourg Saint-Martin 75010 Paris PRENDRE RENDEZ-VOUS', 'https://media.doctolib.com/image/upload/q_auto:eco,f_auto,dpr_2/w_62,h_62,c_fill,g_face/default_doctor_avatar_m'], ["Dr Camille REMURIER Chirurgien-dentiste 26 Bis Rue d'Alleray 75015 Paris Conventionné PRENDRE RENDEZ-VOUS", 'https://media.doctolib.com/image/upload/q_auto:eco,f_auto,dpr_2/w_62,h_62,c_fill,g_face/s7qrjzmt5ttsiiqyraho'], ["Centre d'orthodontie et de pédodontie Paris Reuilly Centre dentaire 2 pédodontistes 18 Boulevard de Reuilly 75012 Paris Établissement conventionné PRENDRE RENDEZ-VOUS", 'https://media.doctolib.com/image/upload/q_auto:eco,f_auto,dpr_2/w_62,h_62,c_fill,g_face/ggdu9fwafhozziqrnbat'], ['Dr Edouard LE ROUX Chirurgien-dentiste 12 Rue Choron 75009 Paris Conventionné PRENDRE RENDEZ-VOUS', 'https://media.doctolib.com/image/upload/q_auto:eco,f_auto,dpr_2/w_62,h_62,c_fill,g_face/rf9b1zqf1ktouftnk6ux'], ["Dr Remy BENZAQUEN Chirurgien-dentiste 8 Rue du Champ de l'Alouette 75013 Paris Conventionné PRENDRE RENDEZ-VOUS", 'https://media.doctolib.com/image/upload/q_auto:eco,f_auto,dpr_2/w_62,h_62,c_fill,g_face/ur4pjmzz2zyxzms0nw5v'], ['Dr Valérie Nguyen Chirurgien-dentiste 10 Boulevard Malesherbes 75008 Paris Conventionné PRENDRE RENDEZ-VOUS', 'https://media.doctolib.com/image/upload/q_auto:eco,f_auto,dpr_2/w_62,h_62,c_fill,g_face/tubswuqsbhheg8thyld9'], ['Dr Jean-Pierre COMPAN Chirurgien-dentiste 22 Boulevard Saint-Germain 75005 Paris Conventionné PRENDRE RENDEZ-VOUS', 'https://media.doctolib.com/image/upload/q_auto:eco,f_auto,dpr_2/w_62,h_62,c_fill,g_face/bbqcvez9des2gxdcwlmo'], ['Dr Jean Claude COSTECALDE Chirurgien-dentiste 170 Rue Legendre 75017 Paris Conventionné PRENDRE RENDEZ-VOUS', 'https://media.doctolib.com/image/upload/q_auto:eco,f_auto,dpr_2/w_62,h_62,c_fill,g_face/xmvp4s8oubgjerrq7ze1'], ['Dr Sabrina Soltani Chirurgien-dentiste 192 Boulevard de Charonne 75020 Paris PRENDRE RENDEZ-VOUS', 'https://media.doctolib.com/image/upload/q_auto:eco,f_auto,dpr_2/w_62,h_62,c_fill,g_face/ketbbovkqduxdxxjyh9j'], ['Dr Patrice MAZLOUM Chirurgien-dentiste 7 Rue Saint-Amand 75015 Paris Conventionné PRENDRE RENDEZ-VOUS', 'https://media.doctolib.com/image/upload/q_auto:eco,f_auto,dpr_2/w_62,h_62,c_fill,g_face/yuhhoztk7s1qt4wu0rzx ...

# %% [markdown]
# # **Partie 2 - Collectes automatisée | [Les Echos](https://www.lesechos.fr/)**
#
#
#
# <br>
#
# <br>
#
#
# <img src = 'https://upload.wikimedia.org/wikipedia/fr/thumb/b/bb/Les_echos_%28logo%29.svg/1200px-Les_echos_%28logo%29.svg.png'>
#
# <br><br>
#
# Les informations que nous souhaitons collecter sont les suivantes :
#
# - l’auteur,
# - la date de publication,
# - le titre,
# - le contenu de la page,

# %%
from selenium import webdriver
import time
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome("./chromedriver")

driver.get("https://www.lesechos.fr/")
# Out:
# C:\Users\antoi\AppData\Local\Temp\ipykernel_13780\3745523284.py:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("./chromedriver")

# %%
driver.find_element(By.ID, "didomi-notice-agree-button").click()

time.sleep(2)

driver.find_element(By.CLASS_NAME, "sc-14kwckt-16 sc-16o6ckw-0 WiTvs bvLlpL sc-ctlfsq-0 lnDWGz".replace(' ', '.')).click()

time.sleep(2)

# %%
driver.find_element(By.CLASS_NAME, "sc-1hma9em-0 fMHhFr".replace(' ', '.')).click()

# %%
driver.find_element(By.CLASS_NAME, "sc-14kwckt-28 sc-ywv8p0-0 sc-166k8it-1 wwuyu jCZKki cQRcWN".replace(' ', '.')).send_keys(Keys.BACK_SPACE*100)
driver.find_element(By.CLASS_NAME, "sc-14kwckt-28 sc-ywv8p0-0 sc-166k8it-1 wwuyu jCZKki cQRcWN".replace(' ', '.')).send_keys("Intelligence artificielle")
time.sleep(1)
driver.find_element(By.CLASS_NAME, "sc-14kwckt-28 sc-ywv8p0-0 sc-166k8it-1 wwuyu jCZKki cQRcWN".replace(' ', '.')).send_keys(Keys.ENTER)

time.sleep(2)

# %%
articles = driver.find_elements(By.CLASS_NAME, "sc-1vhx99f-0 PiyDN".replace(' ', '.'))
print(len(articles))
print(articles)
print(articles[1].text)
# Out:
# 20
# Conex passe dans le giron de 21 Invest France
# Publié à 9:01
# Mis à jour à 9:38
# Déjà numéro un français des logiciels de procédures douanières, l'entreprise du Nord vise désormais le premier rang européen.
# Hauts-de-France

# %%
def navigate_to_article(article):
    print("in")
    try:
        print(article.find_element(By.CLASS_NAME, "sc-iphbbg-1 kCuVyE".replace(' ', '.')))
        # get from a tag the href value
        print(article.find_element(By.CLASS_NAME, "sc-mzdmh8-0 eMxgTp sc-2sd3nw-0 jZoKfW".replace(' ', '.')).get_attribute("href"))
        driver.get(article.find_element(By.CLASS_NAME, "sc-mzdmh8-0 eMxgTp sc-2sd3nw-0 jZoKfW".replace(' ', '.')).get_attribute("href"))

        time.sleep(2)

        try: 
            author = driver.find_element(By.CLASS_NAME, "sc-kla0ai-0 hEKJIU".replace(' ', '.')).text
            author = author.split('\n')[1]
            print(author)
        except:
            # check in the scripts tag to found dict author and get the name
            author = driver.find_element(By.TAG_NAME, "script").get_attribute("innerHTML")
            author = author.split('author":')[1]
            author = author.split('}')[0]
            author = author.split('"')[1]
            print("error")
            print(author)
        driver.back()
        return author


    except:
        print("error")

def collect_data(selection):
    data = []
    for item in selection:
        img = ""
        try:
            img = item.find_element(By.CLASS_NAME, "sc-14kwckt-20 lkbqFA".replace(' ', '.'))
            img = img.get_attribute("src")
        except:
            img = None
        # img = item.find_element(By.CLASS_NAME, "sc-14kwckt-20 lkbqFA".replace(' ', '.'))
        arrOfStrings = item.text.split('\n')
        title = ""
        author = navigate_to_article(item)
        if len(arrOfStrings[0]) >15:
            title = arrOfStrings[0]
        else:
            title = arrOfStrings[1]
        data.append([title, img])
        time.sleep(2)
    return data

# %%
collect_data(articles)
# Out:
# in
# <selenium.webdriver.remote.webelement.WebElement (session="db43cb38955b4d9db855e63d56049517", element="F88A5AA47B26AB0C10F8B87E52F3EF45_element_82")>
# https://www.lesechos.fr/finance-marches/marches-financiers/le-cac-40-caracole-a-son-plus-haut-niveau-historique-2040808
# Bastien Bouchaud
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# Cell In [473], line 1
# ----> 1 collect_data(articles)
#
# Cell In [472], line 40, in collect_data(selection)
#      38     img = None
#      39 # img = item.find_element(By.CLASS_NAME, "sc-14kwckt-20 lkbqFA".replace(' ', '.'))
# ---> 40 arrOfStrings = item.text.split('\n')
#      41 title = ""
#      42 author = navigate_to_article(item)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\selenium\webdriver\remote\webelement.py:84, in WebElement.text(self)
#      81 @property
#      82 def text(self) -> str:
#      83     """The text of the element."""
# ---> 84     return self._execute(Command.GET_ELEMENT_TEXT)['value']
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\selenium\webdriver\remote\webelement.py:396, in WebElement._execute(self, command, params)
#     394     params = {}
#     395 params['id'] = self._id
# --> 396 return self._parent.execute(command, params)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\selenium\webdriver\remote\webdriver.py:435, in WebDriver.execute(self, driver_command, params)
#     433 response = self.command_executor.execute(driver_command, params)
#     434 if response:
# --> 435     self.error_handler.check_response(response)
#     436     response['value'] = self._unwrap_value(
#     437         response.get('value', None))
#     438     return response
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\selenium\webdriver\remote\errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     245         alert_text = value['alert'].get('text')
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# StaleElementReferenceException: Message: stale element reference: stale element not found
#   (Session info: chrome=120.0.6099.71)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF736484D02+56194]
# 	(No symbol) [0x00007FF7363F04B2]
# 	(No symbol) [0x00007FF7362976AA]
# 	(No symbol) [0x00007FF7362A79BF]
# 	(No symbol) [0x00007FF73629DB89]
# 	(No symbol) [0x00007FF73629BF22]
# 	(No symbol) [0x00007FF73629F38F]
# 	(No symbol) [0x00007FF73629F480]
# 	(No symbol) [0x00007FF7362DB97E]
# 	(No symbol) [0x00007FF736305E7A]
# 	(No symbol) [0x00007FF7362D6226]
# 	(No symbol) [0x00007FF736306320]
# 	(No symbol) [0x00007FF736322786]
# 	(No symbol) [0x00007FF736305C23]
# 	(No symbol) [0x00007FF7362D4A45]
# 	(No symbol) [0x00007FF7362D5AD4]
# 	GetHandleVerifier [0x00007FF7367FD5BB+3695675]
# 	GetHandleVerifier [0x00007FF736856197+4059159]
# 	GetHandleVerifier [0x00007FF73684DF63+4025827]
# 	GetHandleVerifier [0x00007FF73651F029+687785]
# 	(No symbol) [0x00007FF7363FB508]
# 	(No symbol) [0x00007FF7363F7564]
# 	(No symbol) [0x00007FF7363F76E9]
# 	(No symbol) [0x00007FF7363E8094]
# 	BaseThreadInitThunk [0x00007FFE6650257D+29]
# 	RtlUserThreadStart [0x00007FFE6710AA58+40]

# %% [markdown]
# ---
# # **Partie 3 : Programation Orientée Objet et Gestion d'une base de données**
#
#
#
# ### **1. Définition d'une Classe**
# **Definition**
#
# La programmation orientée objet (POO) est un paradigme de programmation qui repose sur le concept d'objets. Dans ce paradigme, le code est organisé autour d'entités appelées "objets", qui représentent des instances concrètes ou abstraites de concepts du monde réel. Chaque objet peut avoir des propriétés (appelées attributs) et des comportements (appelés méthodes).
#
# Voici quelques concepts clés de la programmation orientée objet :
#
# - **Objets** : Les objets sont des instances spécifiques d'une classe, qui est un modèle ou un plan pour créer des objets. Par exemple, si une classe est définie pour représenter des voitures, un objet spécifique pourrait être une voiture particulière.
#
# - **Classes** : Les classes sont des structures qui définissent la manière dont les objets sont créés. Elles définissent les attributs (caractéristiques) et les méthodes (comportements) que les objets de la classe auront. Une classe est une sorte de modèle à partir duquel des objets peuvent être créés.
#
# - **Encapsulation** : L'encapsulation est le principe de regrouper les données (attributs) et les méthodes qui les manipulent au sein d'une même entité, c'est-à-dire une classe. Cela permet de cacher les détails d'implémentation et d'isoler le fonctionnement interne de l'objet.
#
# - **Héritage** : L'héritage est un mécanisme qui permet à une classe d'hériter des propriétés et des méthodes d'une autre classe. Cela favorise la réutilisation du code et la création de hiérarchies de classes.
#
# - **Polymorphisme** : Le polymorphisme permet à un même nom de méthode d'avoir des comportements différents en fonction du contexte. Il existe deux types de polymorphisme : le polymorphisme statique (surcharge) et le polymorphisme dynamique (redéfinition).
#
# - **Abstraction** : L'abstraction consiste à simplifier un concept complexe en modélisant uniquement les aspects pertinents tout en masquant les détails complexes.
#
#       # Déclaration d'une classe, paramètre 1 et 2 seront
#
#       class NomDeLaClasse:
#         # Définition des attributs au moment de l'instanciation
#         def __init__(self, parametre1, parametre2):
#           self.parametre1 = parametre1
#           self.parametre2 = parametre2
#
#         def __repr__(self):
#           return "Exemple de retour"
#
#         # Définition d'une méthode
#         def nom_de_la_methode(self, p1, p2):
#           self.value = p1 * p2 # Création d'un nouvel attribut
#
#       # Instance de classe
#       objet = NomDeLaClasse('parametre1', 'parametre2')
#
#       # Héritage :
#       class ClasseFille(NomDeLaClasseMère):
#         def __init__(self, parametre1, parametre2, parametre3):
#           NomDeLaClasseMère.__init__(self, parametre1, parametre2)
#           self.parametre3 = parametre3
#
#         # Méthode utilisable uniquement dans la classe :
#         def __methode_encapsulee(self):
#           print("Test")
#
#
# - __init__: permet de définir les attributs nécessaires à l'objet lors de son instanciation.
# - __repr__: permet de définir le type d'objet retourné par défaut.
# - __str__ : permet de définir ce qui est affiché par défaut lorsque l'on print un objet.
# - __add__ : permet de définir ce ci se produit lorsque l'on additionne des objets entre eux.

# %%
# Définir une classe

class Voiture:
    def __init__(self, couleur:str, marque:str, modele:str, kilometrage:int=10):
        self.couleur = couleur
        self.marque = marque
        self.modele = modele
        self.kilometrage = kilometrage

    def voyage(self, destination, estimation, distance):
        """
        Perform a voyage to the specified destination.

        Args:
            destination (str): The destination of the voyage.
            estimation (str): The estimated time of arrival.
            distance (float): The distance traveled during the voyage.

        Returns:
            str: The current position after the voyage.
        """
        self.destination = destination
        self.estimation = estimation

        self.kilometrage += distance

        return f"Position actuelle {self.destination}"
    
    def show_data(self, *args):
        for arg in args:
            print(arg)

    def show_data_kwargs(self, **kwargs):
        print(kwargs)

# %%
# Instancier un objet
voiture = Voiture("bleu", "Alpine", "A110", 1000)

# Accéder aux attributs
print(voiture.couleur)
print(voiture.marque)
print(voiture.modele)
# Out:
# bleu
# Alpine
# A110

# %%
voiture.voyage("Paris", "12h00", 100)
voiture.show_data(voiture.couleur, voiture.marque, voiture.modele)
voiture.show_data_kwargs(couleur=voiture.couleur, marque=voiture.marque, modele=voiture.modele)
# Out:
# bleu
# Alpine
# A110
# {'couleur': 'bleu', 'marque': 'Alpine', 'modele': 'A110'}

# %%
# Héritage

# %% [markdown]
# ### **2. Gestion d'une base de données avec la bibliothèque [SQLalchemy](https://docs.sqlalchemy.org/en/14/)**
#
# <img src='https://miro.medium.com/v2/resize:fit:1400/0*msfsws06ImMSJYop.jpg'>
#
# SQLAlchemy est une bibliothèque Python très populaire qui facilite l'interaction avec des bases de données relationnelles en utilisant un langage Python. Elle fournit un ensemble d'outils puissants pour travailler avec des bases de données SQL tout en offrant une abstraction flexible qui permet de travailler avec différents types de bases de données.
#
# Voici quelques caractéristiques clés de SQLAlchemy :
#
# **ORM (Object-Relational Mapping)** : SQLAlchemy propose un ORM qui permet de représenter des tables de base de données sous forme d'objets Python. Ces objets peuvent être manipulés comme n'importe quel autre objet Python, offrant ainsi une abstraction plus élevée des opérations sur la base de données.
#
# **Prise en Charge de Diverses Bases de Données** : SQLAlchemy prend en charge plusieurs types de bases de données, y compris MySQL, PostgreSQL, SQLite, Oracle, et d'autres.
#
# **Flexibilité** : Vous pouvez utiliser SQLAlchemy de manière transparente avec un ORM complet, un langage SQL pur, ou une combinaison des deux, en fonction des besoins de votre application.
#
# **Communauté Active** : SQLAlchemy est largement utilisé dans la communauté Python et dispose d'une documentation complète et d'une base d'utilisateurs active.
#
# ---
#
#
# 1. Installation de la bibliothèque : `pip install SQLAlchemy`
#
# 2. Installez [SQLite Viewer](https://marketplace.visualstudio.com/items?itemName=qwtel.sqlite-viewer) pour visualiser votre base données.
#
# <img src='https://qwtel.gallerycdn.vsassets.io/extensions/qwtel/sqlite-viewer/0.3.13/1691231169503/Microsoft.VisualStudio.Services.Icons.Default'>

# %%
# Gestion d'une base de données
import sqlalchemy as db

class DataBase():
    def __init__(self, name_database='database'):
        self.name = name_database
        self.url = f"sqlite:///{name_database}.db"
        self.engine = db.create_engine(self.url)
        self.connection = self.engine.connect()
        self.metadata = db.MetaData()
        self.table = self.engine.table_names()


    def create_table(self, name_table, **kwargs):
        colums = [db.Column(k, v, primary_key = True) if 'id_' in k else db.Column(k, v) for k,v in kwargs.items()]
        db.Table(name_table, self.metadata, *colums)
        self.metadata.create_all(self.engine)
        print(f"Table : '{name_table}' are created succesfully")

    def read_table(self, name_table, return_keys=False):
        table = db.Table(name_table, self.metadata, autoload=True, autoload_with=self.engine)
        if return_keys:table.columns.keys()
        else : return table


    def add_row(self, name_table, **kwarrgs):
        name_table = self.read_table(name_table)

        stmt = (
            db.insert(name_table).
            values(kwarrgs)
        )
        self.connection.execute(stmt)
        print(f'Row id added')


    def delete_row_by_id(self, table, id_):
        name_table = self.read_table(name_table)

        stmt = (
            db.delete(name_table).
            where(students.c.id_ == id_)
            )
        self.connection.execute(stmt)
        print(f'Row id {id_} deleted')

    def select_table(self, name_table):
        name_table = self.read_table(name_table)
        stm = db.select([name_table])
        return self.connection.execute(stm).fetchall()

# %%
# Création d'une base de données
database = DataBase('data')
# Out:
# C:\Users\antoi\AppData\Local\Temp\ipykernel_13780\1471672439.py:11: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   self.table = self.engine.table_names()

# %%
# Création d'un Tableau1
database.create_table('Tableau1', id_user=db.Integer, colonne1=db.String, colonne2=db.Integer)
# Out:
# Table : 'Tableau1' are created succesfully

# %%
# Création d'un Tableau2
database.create_table('Tableau2', id_shop=db.Integer, id_colonne1=db.String, colonne2=db.Integer)
# Out:
# Table : 'Tableau2' are created succesfully

# %%
# Ajouter une ligne à la base de données
database.add_row('Tableau2', id_shop=3086, id_colonne1='Iphone')
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sqlalchemy\engine\base.py:1770, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1769     if not evt_handled:
# -> 1770         self.dialect.do_execute(
#    1771             cursor, statement, parameters, context
#    1772         )
#    1774 if self._has_events or self.engine._has_events:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sqlalchemy\engine\default.py:717, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     716 def do_execute(self, cursor, statement, parameters, context=None):
# --> 717     cursor.execute(statement, parameters)
#
# IntegrityError: UNIQUE constraint failed: Tableau2.id_shop, Tableau2.id_colonne1
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# Cell In [496], line 2
#       1 # Ajouter une ligne à la base de données
# ----> 2 database.add_row('Tableau2', id_shop=3086, id_colonne1='Iphone')
#
# Cell In [492], line 33, in DataBase.add_row(self, name_table, **kwarrgs)
#      27 name_table = self.read_table(name_table)
#      29 stmt = (
#      30     db.insert(name_table).
#      31     values(kwarrgs)
#      32 )
# ---> 33 self.connection.execute(stmt)
#      34 print(f'Row id added')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sqlalchemy\engine\base.py:1262, in Connection.execute(self, statement, *multiparams, **params)
#    1258     util.raise_(
#    1259         exc.ObjectNotExecutableError(statement), replace_context=err
#    1260     )
#    1261 else:
# -> 1262     return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sqlalchemy\sql\elements.py:323, in ClauseElement._execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     319 def _execute_on_connection(
#     320     self, connection, multiparams, params, execution_options, _force=False
#     321 ):
#     322     if _force or self.supports_execution:
# --> 323         return connection._execute_clauseelement(
#     324             self, multiparams, params, execution_options
#     325         )
#     326     else:
#     327         raise exc.ObjectNotExecutableError(self)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sqlalchemy\engine\base.py:1451, in Connection._execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1439 compiled_cache = execution_options.get(
#    1440     "compiled_cache", self.engine._compiled_cache
#    1441 )
#    1443 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1444     dialect=dialect,
#    1445     compiled_cache=compiled_cache,
#    (...)
#    1449     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1450 )
# -> 1451 ret = self._execute_context(
#    1452     dialect,
#    1453     dialect.execution_ctx_cls._init_compiled,
#    1454     compiled_sql,
#    1455     distilled_params,
#    1456     execution_options,
#    1457     compiled_sql,
#    1458     distilled_params,
#    1459     elem,
#    1460     extracted_params,
#    1461     cache_hit=cache_hit,
#    1462 )
#    1463 if has_events:
#    1464     self.dispatch.after_execute(
#    1465         self,
#    1466         elem,
#    (...)
#    1470         ret,
#    1471     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sqlalchemy\engine\base.py:1813, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1810             branched.close()
#    1812 except BaseException as e:
# -> 1813     self._handle_dbapi_exception(
#    1814         e, statement, parameters, cursor, context
#    1815     )
#    1817 return result
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sqlalchemy\engine\base.py:1994, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1992     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1993 elif should_wrap:
# -> 1994     util.raise_(
#    1995         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1996     )
#    1997 else:
#    1998     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sqlalchemy\util\compat.py:207, in raise_(***failed resolving arguments***)
#     204     exception.__cause__ = replace_context
#     206 try:
# --> 207     raise exception
#     208 finally:
#     209     # credit to
#     210     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     211     # as the __traceback__ object creates a cycle
#     212     del exception, replace_context, from_, with_traceback
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sqlalchemy\engine\base.py:1770, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1768                 break
#    1769     if not evt_handled:
# -> 1770         self.dialect.do_execute(
#    1771             cursor, statement, parameters, context
#    1772         )
#    1774 if self._has_events or self.engine._has_events:
#    1775     self.dispatch.after_cursor_execute(
#    1776         self,
#    1777         cursor,
#    (...)
#    1781         context.executemany,
#    1782     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sqlalchemy\engine\default.py:717, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     716 def do_execute(self, cursor, statement, parameters, context=None):
# --> 717     cursor.execute(statement, parameters)
#
# IntegrityError: (sqlite3.IntegrityError) UNIQUE constraint failed: Tableau2.id_shop, Tableau2.id_colonne1
# [SQL: INSERT INTO "Tableau2" (id_shop, id_colonne1) VALUES (?, ?)]
# [parameters: (3086, 'Iphone')]
# (Background on this error at: http://sqlalche.me/e/14/gkpj)

# %%
# Ajouter plusieurs lignes à la base de données
for i in range(10):
    database.add_row('Tableau2',id_shop=i, id_colonne1='Iphone'*(i+1), colonne2=99*i)

database.select_table('Tableau2')
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sqlalchemy\engine\base.py:1770, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1769     if not evt_handled:
# -> 1770         self.dialect.do_execute(
#    1771             cursor, statement, parameters, context
#    1772         )
#    1774 if self._has_events or self.engine._has_events:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sqlalchemy\engine\default.py:717, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     716 def do_execute(self, cursor, statement, parameters, context=None):
# --> 717     cursor.execute(statement, parameters)
#
# IntegrityError: UNIQUE constraint failed: Tableau2.id_shop, Tableau2.id_colonne1
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# Cell In [497], line 3
#       1 # Ajouter plusieurs lignes à la base de données
#       2 for i in range(10):
# ----> 3     database.add_row('Tableau2',id_shop=i, id_colonne1='Iphone'*(i+1), colonne2=99*i)
#       5 database.select_table('Tableau2')
#
# Cell In [492], line 33, in DataBase.add_row(self, name_table, **kwarrgs)
#      27 name_table = self.read_table(name_table)
#      29 stmt = (
#      30     db.insert(name_table).
#      31     values(kwarrgs)
#      32 )
# ---> 33 self.connection.execute(stmt)
#      34 print(f'Row id added')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sqlalchemy\engine\base.py:1262, in Connection.execute(self, statement, *multiparams, **params)
#    1258     util.raise_(
#    1259         exc.ObjectNotExecutableError(statement), replace_context=err
#    1260     )
#    1261 else:
# -> 1262     return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sqlalchemy\sql\elements.py:323, in ClauseElement._execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     319 def _execute_on_connection(
#     320     self, connection, multiparams, params, execution_options, _force=False
#     321 ):
#     322     if _force or self.supports_execution:
# --> 323         return connection._execute_clauseelement(
#     324             self, multiparams, params, execution_options
#     325         )
#     326     else:
#     327         raise exc.ObjectNotExecutableError(self)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sqlalchemy\engine\base.py:1451, in Connection._execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1439 compiled_cache = execution_options.get(
#    1440     "compiled_cache", self.engine._compiled_cache
#    1441 )
#    1443 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1444     dialect=dialect,
#    1445     compiled_cache=compiled_cache,
#    (...)
#    1449     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1450 )
# -> 1451 ret = self._execute_context(
#    1452     dialect,
#    1453     dialect.execution_ctx_cls._init_compiled,
#    1454     compiled_sql,
#    1455     distilled_params,
#    1456     execution_options,
#    1457     compiled_sql,
#    1458     distilled_params,
#    1459     elem,
#    1460     extracted_params,
#    1461     cache_hit=cache_hit,
#    1462 )
#    1463 if has_events:
#    1464     self.dispatch.after_execute(
#    1465         self,
#    1466         elem,
#    (...)
#    1470         ret,
#    1471     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sqlalchemy\engine\base.py:1813, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1810             branched.close()
#    1812 except BaseException as e:
# -> 1813     self._handle_dbapi_exception(
#    1814         e, statement, parameters, cursor, context
#    1815     )
#    1817 return result
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sqlalchemy\engine\base.py:1994, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1992     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1993 elif should_wrap:
# -> 1994     util.raise_(
#    1995         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1996     )
#    1997 else:
#    1998     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sqlalchemy\util\compat.py:207, in raise_(***failed resolving arguments***)
#     204     exception.__cause__ = replace_context
#     206 try:
# --> 207     raise exception
#     208 finally:
#     209     # credit to
#     210     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     211     # as the __traceback__ object creates a cycle
#     212     del exception, replace_context, from_, with_traceback
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sqlalchemy\engine\base.py:1770, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1768                 break
#    1769     if not evt_handled:
# -> 1770         self.dialect.do_execute(
#    1771             cursor, statement, parameters, context
#    1772         )
#    1774 if self._has_events or self.engine._has_events:
#    1775     self.dispatch.after_cursor_execute(
#    1776         self,
#    1777         cursor,
#    (...)
#    1781         context.executemany,
#    1782     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sqlalchemy\engine\default.py:717, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     716 def do_execute(self, cursor, statement, parameters, context=None):
# --> 717     cursor.execute(statement, parameters)
#
# IntegrityError: (sqlite3.IntegrityError) UNIQUE constraint failed: Tableau2.id_shop, Tableau2.id_colonne1
# [SQL: INSERT INTO "Tableau2" (id_shop, id_colonne1, colonne2) VALUES (?, ?, ?)]
# [parameters: (0, 'Iphone', 0)]
# (Background on this error at: http://sqlalche.me/e/14/gkpj)

# %%
# Afficher le Tableau1
database.select_table('Tableau2')
# Out:
# [(3086, 'Iphone', None),
#  (0, 'Iphone', 0),
#  (1, 'IphoneIphone', 99),
#  (2, 'IphoneIphoneIphone', 198),
#  (3, 'IphoneIphoneIphoneIphone', 297),
#  (4, 'IphoneIphoneIphoneIphoneIphone', 396),
#  (5, 'IphoneIphoneIphoneIphoneIphoneIphone', 495),
#  (6, 'IphoneIphoneIphoneIphoneIphoneIphoneIphone', 594),
#  (7, 'IphoneIphoneIphoneIphoneIphoneIphoneIphoneIphone', 693),
#  (8, 'IphoneIphoneIphoneIphoneIphoneIphoneIphoneIphoneIphone', 792),
#  (9, 'IphoneIphoneIphoneIphoneIphoneIphoneIphoneIphoneIphoneIphone', 891)]

# %% [markdown]
# # Exercice Collecte d’articles sur le site [Cdiscount](https://www.cdiscount.com/)
#
# <img src='https://marketplace.cdiscount.com/wp-content/uploads/2020/06/french-days-cdiscount.jpg'>
#
# Dans cet exercice nous allons collecter les informations des articles présents sur le site Cdiscount.
# Parmis une liste de produit, collectez dans une base de données les informations suivantes :
# - le nom de l’article,
# - le lien de l’image,
# - le lien de l’article
# - le prix de l’article
# - la note de l’article
#
# Nous créerons un script qui automatisera la collecte des données en prenant en compte les exceptions et qui retournera un fichier csv contenant l'ensemble de nos données. Voici la liste des produits à collecter (choisir un article) :
# - Iphone 13
# - Samsung Galaxy S21
# - Xiaomi Redmi Note 10
#
# 1. Créez une fonction `collecte_Cdiscount` qui prends en entrée une chaine de caractère (produit à collecter) et qui retourne un fichier csv contenant les produits scrappé avec la bibliothèque Selenium.
# 2. Placez vcette fonction dans un fichier `functions.py`.
# 3. Créez une page dans votre application streamlit qui demande à l'utilisateur de saisir le nom d'un produit à collecter puis fait appel à la fonction `collecte_Cdiscount` pour collecter ces produits. La collecte ne doit pas ouvrir de navigateur.
# 4. Ajoutez les données dans une base de données MySQL ou SQL Lite.

# %%
from selenium import webdriver
import time
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys


# def search_articles(keyword):
driver = webdriver.Chrome("./chromedriver")
driver.get("https://www.dealabs.com/")

time.sleep(2)

driver.find_element(By.CLASS_NAME, "overflow--wrap-on flex--grow-1 flex--fromW3-grow-0 width--fromW3-ctrl-m space--mb-3 space--fromW3-mb-0 space--fromW3-mr-2 button button--shape-circle button--type-primary button--mode-brand".replace(" ", ".")).click()

time.sleep(0.5)


# search_articles("iphone")
# Out:
# C:\Users\antoi\AppData\Local\Temp\ipykernel_13780\4026374517.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("./chromedriver")

# %%
driver.find_element(By.CLASS_NAME, "input width--all-12 input-with-icon--l input--search".replace(" ", ".")).click()

driver.find_element(By.CLASS_NAME, "input width--all-12 input-with-icon--l input--search".replace(" ", ".")).send_keys("iphone")

driver.find_element(By.CLASS_NAME, "input width--all-12 input-with-icon--l input--search".replace(" ", ".")).send_keys(Keys.ENTER)


time.sleep(2)

# %%
def disable_popup():
    try: 
        driver.find_element(By.CLASS_NAME, "space--ml-a button button--shape-circle button--type-tertiary button--mode-default button--size-s button--square".replace(" ", ".")).click()
    except:
        pass

disable_popup()

# %%
articles = driver.find_elements(By.CLASS_NAME, "thread cept-thread-item thread--type-list imgFrame-container--scale thread--deal".replace(" ", "."))

print(len(articles))
# Out:
# 29

# %%
def collect_data(articles):
    datas = []
    for article in articles:
        data = {}
        img = ""
        link = ""
        price  = ""
        name = ""
        seller = ""
        # pattern = keyword


        try:
            img = article.find_element(By.CLASS_NAME, "thread-image width--all-auto height--all-auto imgFrame-img".replace(' ', '.')).get_attribute("src")
        except:
            pass
        try:
            link = article.find_element(By.CLASS_NAME, "cept-tt thread-link linkPlain thread-title--list js-thread-title".replace(' ', '.')).get_attribute("href")
        except:
            pass
        try:
            price = article.find_element(By.CLASS_NAME, "thread-price text--b cept-tp size--all-l size--fromW3-xl".replace(' ', '.')).text
        except:
            pass
        try:
            name = article.find_element(By.CLASS_NAME, "cept-tt thread-link linkPlain thread-title--list js-thread-title".replace(' ', '.')).text
        except:
            pass
        try:
            seller = article.find_element(By.CLASS_NAME, "overflow--wrap-off text--b text--color-brandPrimary link".replace(' ', '.')).text
        except:
            pass

        data = {
            "img": img,
            "link": link,
            "price": price,
            "name": name,
            "seller": seller
        }
        print(data)
        datas.append(data)
    return datas

dataCollected = collect_data(articles)
# Out:
# {'img': 'https://static-pepper.dealabs.com/threads/raw/0FDTV/2689885_1/re/300x300/qt/60/2689885_1.jpg', 'link': 'https://www.dealabs.com/bons-plans/otterbox-fre-coque-pour-iphone-14-plus-avec-magsafe-2689885', 'price': '20,90€', 'name': 'Coque de protection OtterBox Fre pour iPhone 14 Plus avec MagSafe', 'seller': 'Amazon'}
# {'img': 'https://static-pepper.dealabs.com/threads/raw/ii9eT/2689784_1/re/300x300/qt/60/2689784_1.jpg', 'link': 'https://www.dealabs.com/bons-plans/cables-lightning-x2-usb-vers-lightning-amazon-basics-2689784', 'price': '8,24€', 'name': 'Lot de 2 câbles Lightning vers USB A Amazon Basics - certifié MFi, noir, 1,8 m', 'seller': 'Amazon'}
# {'img': 'https://static-pepper.dealabs.com/threads/raw/1tEii/2689983_1/re/300x300/qt/60/2689983_1.jpg', 'link': 'https://www.dealabs.com/bons-plans/apple-iphone-15-jaune-128-go-2689983', 'price': '825,24€', 'name': 'Smartphone 6,1" Apple iPhone 15 - 128 Go', 'seller': 'Amazon.it'}
# {'img': 'https://static-pepper.dealabs.com/threads/raw/jOjjv/2690064_1/re/300x300/qt/60/2690064_1.jpg', 'link': 'https://www.dealabs.com/bons-plans/adaptateur-carplay-sans-fil-pour-iphone-2690064', 'price': '35,99€', 'name': 'Adaptateur CarPlay sans Fil pour iPhone Olycism (Vendeur tiers)', 'seller': 'Amazon'}
# {'img': 'https://static-pepper.dealabs.com/threads/raw/1Jnex/2689375_1/re/300x300/qt/60/2689375_1.jpg', 'link': 'https://www.dealabs.com/bons-plans/80-de-reduction-livraison-gratuite-sur-une-selection-de-coques-ex-coque-transparente-krystec-avec-halolock-pour-apple-iphone-14-pro-2689375', 'price': '6€', 'name': '80% de réduction + Livraison gratuite sur une sélection de coques - Ex : Coque transparente Krystec avec HaloLock pour Apple iPhone 14 Pro', 'seller': 'ESR'}
# {'img': 'https://static-pepper.dealabs.com/threads/raw/g7hKr/2688361_1/re/300x300/qt/60/2688361_1.jpg', 'link': 'https://www.dealabs.com/bons-plans/10-sur-une-large-et-bonne-selection-de-produits-high-tech-2688361', 'price': '', 'name': '10% de réduction sur une large sélection de produits high-tech (Frontaliers Suisse)', 'seller': ''}
# {'img': 'https://static-pepper.dealabs.com/threads/raw/WGRmm/2688917_1/re/300x300/qt/60/2688917_1.jpg', 'link': 'https://www.dealabs.com/bons-plans/manette-dualsense-ps5-plusieurs-coloris-2688917', 'price': '49,99€', 'name': 'Manette sans fil DualSense PS5 - Plusieurs coloris (divers marchands)', 'seller': 'Micromania Zing'}
# {'img': 'https://static-pepper.dealabs.com/threads/raw/C5Dft/2688437_1/re/300x300/qt/60/2688437_1.jpg', 'link': 'https://www.dealabs.com/bons-plans/apple-iphone-12-128go-blanc-reconditionne-excellent-etat-2688437', 'price': '339,99€', 'name': 'APPLE iPhone 12 128Go Blanc - Reconditionné - Excellent état (Vendeur Tiers)', 'seller': 'Cdiscount'}
# {'img': 'https://static-pepper.dealabs.com/threads/raw/h136i/2688916_1/re/300x300/qt/60/2688916_1.jpg', 'link': 'https://www.dealabs.com/bons-plans/anker-chargeur-usb-c-gan-30w-511-nano-3-2688916', 'price': '15,19€', 'name': 'Chargeur USB Type-C Anker - GaN, 30W (vendeur tiers)', 'seller': 'Amazon'}
# {'img': 'https://static-pepper.dealabs.com/threads/raw/albV3/2687874_1/re/300x300/qt/60/2687874_1.jpg', 'link': 'https://www.dealabs.com/bons-plans/iphone-12-128go-blue-sans-kit-pieton-2687874', 'price': '639€', 'name': 'iPhone 12 128Go Blue sans kit piéton', 'seller': 'Cdiscount'}
# {'img': 'https://static-pepper.dealabs.com/threads/raw/fGwmF/2688274_1/re/300x300/qt/60/2688274_1.jpg', 'link': 'https://www.dealabs.com/bons-plans/amazon-basics-cable-usb-c-vers-lightning-180m-2688274', 'price': '7,27€', 'name': 'Câble USB-C vers Lightning Amazon Basics - 1.80m', 'seller': 'Amazon'}
# {'img': 'https://static-pepper.dealabs.com/threads/raw/nZegu/2688127_1/re/300x300/qt/60/2688127_1.jpg', 'link': 'https://www.dealabs.com/bons-plans/apple-iphone-12-61-64-go-double-sim-5g-noir-frontaliers-suisse-2688127', 'price': '473,65€', 'name': 'Smartphone 6.1" Apple Iphone 12 - 64 Go (Frontaliers Suisse)', 'seller': 'Fnac'}

# %%
# Définir une classe

class Deals:
    def __init__(self, img:str, link:str, price:str, name:str, seller:str):
        self.img = img
        self.link = link
        self.price = price
        self.name = name
        self.seller = seller
    
    def show_data(self, *args):
        for arg in args:
            print(arg)

    def show_data_kwargs(self, **kwargs):
        print(kwargs)

# %%
print(dataCollected[0])
# Out:
# {'img': 'https://static-pepper.dealabs.com/threads/raw/0FDTV/2689885_1/re/300x300/qt/60/2689885_1.jpg', 'link': 'https://www.dealabs.com/bons-plans/otterbox-fre-coque-pour-iphone-14-plus-avec-magsafe-2689885', 'price': '20,90€', 'name': 'Coque de protection OtterBox Fre pour iPhone 14 Plus avec MagSafe', 'seller': 'Amazon'}

# %%
deal = Deals(**dataCollected[0])

deal.show_data_kwargs(**dataCollected[0])
# Out:
# {'img': 'https://static-pepper.dealabs.com/threads/raw/0FDTV/2689885_1/re/300x300/qt/60/2689885_1.jpg', 'link': 'https://www.dealabs.com/bons-plans/otterbox-fre-coque-pour-iphone-14-plus-avec-magsafe-2689885', 'price': '20,90€', 'name': 'Coque de protection OtterBox Fre pour iPhone 14 Plus avec MagSafe', 'seller': 'Amazon'}

# %%
# Gestion d'une base de données
import sqlalchemy as db

class DataBase():
    def __init__(self, name_database='dealabs'):
        self.name = name_database
        self.url = f"sqlite:///{name_database}.db"
        self.engine = db.create_engine(self.url)
        self.connection = self.engine.connect()
        self.metadata = db.MetaData()
        self.table = self.engine.table_names()


    def create_table(self, name_table, **kwargs):
        colums = [db.Column(k, v, primary_key = True) if 'id_' in k else db.Column(k, v) for k,v in kwargs.items()]
        db.Table(name_table, self.metadata, *colums)
        self.metadata.create_all(self.engine)
        print(f"Table : '{name_table}' are created succesfully")

    def read_table(self, name_table, return_keys=False):
        table = db.Table(name_table, self.metadata, autoload=True, autoload_with=self.engine)
        if return_keys:table.columns.keys()
        else : return table


    def add_row(self, name_table, **kwarrgs):
        name_table = self.read_table(name_table)

        stmt = (
            db.insert(name_table).
            values(kwarrgs)
        )
        self.connection.execute(stmt)
        print(f'Row id added')


    def delete_row_by_id(self, table, id_):
        name_table = self.read_table(name_table)

        stmt = (
            db.delete(name_table).
            where(students.c.id_ == id_)
            )
        self.connection.execute(stmt)
        print(f'Row id {id_} deleted')

    def select_table(self, name_table):
        name_table = self.read_table(name_table)
        stm = db.select([name_table])
        return self.connection.execute(stm).fetchall()

# %%
database = DataBase('data')
database.create_table('deals', img=db.String, link=db.String, price=db.String, name=db.String, seller=db.String)
i = 0
for line in range(len(dataCollected)):
    database.add_row('deals', **dataCollected[i])
    i += 1

database.select_table('deals')
# Out:
# Table : 'deals' are created succesfully
# Row id added
# Row id added
# Row id added
# Row id added
# Row id added
# Row id added
# Row id added
# Row id added
# Row id added
# Row id added
# Row id added
# Row id added
# Row id added
# Row id added
# C:\Users\antoi\AppData\Local\Temp\ipykernel_13780\2568076193.py:11: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   self.table = self.engine.table_names()
# Row id added
# Row id added
# Row id added
# Row id added
# Row id added
# Row id added
# Row id added
# Row id added
# Row id added
# Row id added
# Row id added
# Row id added
# Row id added
# Row id added
# Row id added
# [('https://static-pepper.dealabs.com/threads/raw/0FDTV/2689885_1/re/300x300/qt/60/2689885_1.jpg', 'https://www.dealabs.com/bons-plans/otterbox-fre-coque-pour-iphone-14-plus-avec-magsafe-2689885', '20,90€', 'Coque de protection OtterBox Fre pour iPhone 14 Plus avec MagSafe', 'Amazon'),
